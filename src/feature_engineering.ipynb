# %% [markdown]
# # Feature Engineering — Soil & Fertilizer
#
# 1. Encode categoricals (Soil Type, Crop Type)
# 2. Add optional features (NPK ratio, Temp×Humidity, moisture bins)
# 3. Scale numeric features
#
# Run cells in order. Run **Load & clean** first.

# %% [markdown]
# ## Load data & clean

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

DATA_PATH = "../data/data/raw/data_core.csv"
TARGET_COL = "Fertilizer Name"

df = pd.read_csv(DATA_PATH)
df = df.fillna(df.mean(numeric_only=True)).fillna("Unknown")

X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL]

print("Shape after load:", X.shape)
print("Columns:", X.columns.tolist())
X.head()
# Out:
# Shape after load: (8000, 8)
# Columns: ['Temperature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type', 'Nitrogen', 'Potassium', 'Phosphorous']
#    Temperature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous
# 0            0
# 1           36
# 2           30
# 3           20
# 4            0

# %% [markdown]
# ## 1. Encode categorical variables (One-Hot)
#
# Soil Type and Crop Type → one-hot encoding so models get numeric input.

# %%
X_encoded = pd.get_dummies(X, columns=["Soil Type", "Crop Type"], prefix=["Soil", "Crop"])
print("Shape after one-hot encoding:", X_encoded.shape)
print("New columns:", X_encoded.columns.tolist())
X_encoded.head()
# Out:
# Shape after one-hot encoding: (8000, 22)
# New columns: ['Temperature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium', 'Phosphorous', 'Soil_Black', 'Soil_Clayey', 'Soil_Loamy', 'Soil_Red', 'Soil_Sandy', 'Crop_Barley', 'Crop_Cotton', 'Crop_Ground Nuts', 'Crop_Maize', 'Crop_Millets', 'Crop_Oil seeds', 'Crop_Paddy', 'Crop_Pulses', 'Crop_Sugarcane', 'Crop_Tobacco', 'Crop_Wheat']
#    Temperature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 0         26.0      52.0      38.0        37          0            0
# 1         29.0      52.0      45.0        12          0           36
# 2         34.0      65.0      62.0         7          9           30
# 3         32.0      62.0      34.0        22          0           20
# 4         28.0      54.0      46.0        35          0            0
#
#    Soil_Black  Soil_Clayey  Soil_Loamy  Soil_Red  ...  Crop_Cotton  \
# 0       False        False       False     False  ...        False
# 1       False        False        True     False  ...        False
# 2        True        False       False     False  ...         True
# 3       False        False       False      True  ...        False
# 4       False         True       False     False  ...        False
#
#    Crop_Ground Nuts  Crop_Maize  Crop_Millets  Crop_Oil seeds  Crop_Paddy  \
# 0             False        True         False           False       False
# 1             False       False         False           False       False
# 2             False       False         False           False       False
# 3             False       False         False           False       False
# 4             False       False         False           False        True
#
#    Crop_Pulses  Crop_Sugarcane  Crop_Tobacco  Crop_Wheat
# 0        False           False         False       False
# 1        False            True         False       False
# 2        False           False         False       False
# 3        False           False          True       False
# 4        False           False         False       False
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 2. Optional new features
#
# - **NPK total** (Nitrogen + Phosphorous + Potassium)
# - **Temp × Humidity** (environment interaction)
# - **Moisture level** (Low / Medium / High bins)

# %%
X_fe = X_encoded.copy()

# NPK total (nutrient load)
X_fe["NPK_total"] = X_fe["Nitrogen"] + X_fe["Phosphorous"] + X_fe["Potassium"]

# Temperature × Humidity interaction
X_fe["Temp_Humidity"] = X_fe["Temperature"] * X_fe["Humidity"]

# Moisture bins: Low/Medium/High (quantile-based)
X_fe["Moisture_level"] = pd.qcut(X_fe["Moisture"], q=3, labels=["Low", "Medium", "High"])
X_fe = pd.get_dummies(X_fe, columns=["Moisture_level"], prefix="Moisture")

print("Shape after new features:", X_fe.shape)
X_fe.head()
# Out:
# Shape after new features: (8000, 27)
#    Temperature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 0         26.0      52.0      38.0        37          0            0
# 1         29.0      52.0      45.0        12          0           36
# 2         34.0      65.0      62.0         7          9           30
# 3         32.0      62.0      34.0        22          0           20
# 4         28.0      54.0      46.0        35          0            0
#
#    Soil_Black  Soil_Clayey  Soil_Loamy  Soil_Red  ...  Crop_Paddy  \
# 0       False        False       False     False  ...       False
# 1       False        False        True     False  ...       False
# 2        True        False       False     False  ...       False
# 3       False        False       False      True  ...       False
# 4       False         True       False     False  ...        True
#
#    Crop_Pulses  Crop_Sugarcane  Crop_Tobacco  Crop_Wheat  NPK_total  \
# 0        False           False         False       False         37
# 1        False            True         False       False         48
# 2        False           False         False       False         46
# 3        False           False          True       False         42
# 4        False           False         False       False         35
#
#    Temp_Humidity  Moisture_Low  Moisture_Medium  Moisture_High
# 0         1352.0         False             True          False
# 1         1508.0         False             True          False
# 2         2210.0         False            False           True
# 3         1984.0          True            False          False
# 4         1512.0         False             True          False
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 3. Scale numeric features
#
# Scale continuous columns so models are not dominated by large ranges. Binary (0/1) columns left as-is.

# %%
# Columns to scale: original numeric + new continuous features
to_scale = ["Temperature", "Humidity", "Moisture", "Nitrogen", "Potassium", "Phosphorous", "NPK_total", "Temp_Humidity"]
to_scale = [c for c in to_scale if c in X_fe.columns]

scaler = StandardScaler()
X_fe[to_scale] = scaler.fit_transform(X_fe[to_scale])

print("Scaled columns:", to_scale)
print("Final feature matrix shape:", X_fe.shape)
X_fe.head()
# Out:
# Scaled columns: ['Temperature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium', 'Phosphorous', 'NPK_total', 'Temp_Humidity']
# Final feature matrix shape: (8000, 27)
#    Temperature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 0    -0.968940 -0.881847 -0.443088  1.566942  -0.712786    -1.397878
# 1    -0.298995 -0.881847  0.112671 -0.542466  -0.712786     1.320481
# 2     0.817579  0.708007  1.462374 -0.964348   0.925227     0.867421
# 3     0.370949  0.341118 -0.760666  0.301297  -0.712786     0.112321
# 4    -0.522310 -0.637254  0.192066  1.398190  -0.712786    -1.397878
#
#    Soil_Black  Soil_Clayey  Soil_Loamy  Soil_Red  ...  Crop_Paddy  \
# 0       False        False       False     False  ...       False
# 1       False        False        True     False  ...       False
# 2        True        False       False     False  ...       False
# 3       False        False       False      True  ...       False
# 4       False         True       False     False  ...        True
#
#    Crop_Pulses  Crop_Sugarcane  Crop_Tobacco  Crop_Wheat  NPK_total  \
# 0        False           False         False       False  -0.392505
# 1        False            True         False       False   0.726612
# 2        False           False         False       False   0.523136
# 3        False           False          True       False   0.116185
# 4        False           False         False       False  -0.595980
#
#    Temp_Humidity  Moisture_Low  Moisture_Medium  Moisture_High
# 0      -1.023047         False             True          False
# 1      -0.678819         False             True          False
# 2       0.870204         False            False           True
# 3       0.371516          True            False          False
# 4      -0.669993         False             True          False
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 4. Final feature matrix & target
#
# Use `X_fe` and `y` for train-test split and model training.

# %%
print("Feature matrix X_fe:", X_fe.shape)
print("Target y:", y.shape)
print("\nAll feature columns:")
print(X_fe.columns.tolist())
print("\nTarget value counts:")
print(y.value_counts().head(10))
# Out:
# Feature matrix X_fe: (8000, 27)
# Target y: (8000,)
#
# All feature columns:
# ['Temperature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium', 'Phosphorous', 'Soil_Black', 'Soil_Clayey', 'Soil_Loamy', 'Soil_Red', 'Soil_Sandy', 'Crop_Barley', 'Crop_Cotton', 'Crop_Ground Nuts', 'Crop_Maize', 'Crop_Millets', 'Crop_Oil seeds', 'Crop_Paddy', 'Crop_Pulses', 'Crop_Sugarcane', 'Crop_Tobacco', 'Crop_Wheat', 'NPK_total', 'Temp_Humidity', 'Moisture_Low', 'Moisture_Medium', 'Moisture_High']
#
# Target value counts:
# Fertilizer Name
# 14-35-14    1188
# Urea        1170
# DAP         1167
# 10-26-26    1128
# 17-17-17    1124
# 28-28       1120
# 20-20       1103
# Name: count, dtype: int64
